# %% [markdown]
# # Scramble the data for each iteration so that it learns the data and not the time
#
# Training a classification model using supervised e-prop plasticity to accumulate evidence.
#
# ## Description
#
# This script demonstrates supervised learning of a classification task with the eligibility propagation (e-prop)
# plasticity mechanism by Bellec et al. [1]_.
#
# This type of learning is demonstrated at the proof-of-concept task in [1]_. We based this script on their
# TensorFlow script given in [2]_.
#
# The task, a so-called evidence accumulation task, is inspired by behavioral tasks, where a lab animal (e.g., a
# mouse) runs along a track, gets cues on the left and right, and has to decide at the end of the track between
# taking a left and a right turn of which one is correct. After a number of iterations, the animal is able to
# infer the underlying rationale of the task. Here, the solution is to turn to the side in which more cues were
# presented.
#
# <img src="file://../../../../pynest/examples/eprop_plasticity/eprop_supervised_classification_schematic_evidence-accumulation.png" width="70 %" alt="See Figure 1 below." align="center">
#
# Learning in the neural network model is achieved by optimizing the connection weights with e-prop plasticity.
# This plasticity rule requires a specific network architecture depicted in Figure 1. The neural network model
# consists of a recurrent network that receives input from Poisson generators and projects onto two readout
# neurons - one for the left and one for the right turn at the end. The input neuron population consists of four
# groups: one group providing background noise of a specific rate for some base activity throughout the
# experiment, one group providing the input spikes of the left cues and one group providing them for the right
# cues, and a last group defining the recall window, in which the network has to decide. The readout neuron
# compares the network signal $\pi_k$ with the teacher target signal $\pi_k^*$, which it receives from
# a rate generator. Since the decision is at the end and all the cues are relevant, the network has to keep the
# cues in memory. Additional adaptive neurons in the network enable this memory. The network's training error is
# assessed by employing a cross-entropy error loss.
#
# Details on the event-based NEST implementation of e-prop can be found in [3]_.
#
# ## References
#
# .. [1] Bellec G, Scherr F, Subramoney F, Hajek E, Salaj D, Legenstein R, Maass W (2020). A solution to the
#        learning dilemma for recurrent networks of spiking neurons. Nature Communications, 11:3625.
#        https://doi.org/10.1038/s41467-020-17236-y
#
# .. [2] https://github.com/IGITUGraz/eligibility_propagation/blob/master/Figure_3_and_S7_e_prop_tutorials/tutorial_evidence_accumulation_with_alif.py
#
# .. [3] Korcsak-Gorzo A, Stapmanns J, Espinoza Valverde JA, Dahmen D, van Albada SJ, Bolten M, Diesmann M.
#        Event-based implementation of eligibility propagation (in preparation)

# %% [markdown]
# ## Import libraries
# We begin by importing all libraries required for the simulation, analysis, and visualization.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import nest
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from cycler import cycler
from IPython.display import Image
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.8.0
#  Built: Aug  5 2024 06:09:47
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %% [markdown]
# ## Schematic of network architecture
# This figure, identical to the one in the description, shows the required network architecture in the center,
# the input and output of the pattern generation task above, and lists of the required NEST device, neuron, and
# synapse models below. The connections that must be established are numbered 1 to 7.

# %%
try:
    Image(filename="./eprop_supervised_classification_schematic_evidence-accumulation.png")
except Exception:
    pass

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Initialize random generator
# We seed the numpy random generator, which will generate random initial weights as well as random input and
# output.

# %%
rng_seed = 1  # numpy random seed
np.random.seed(rng_seed)  # fix numpy random seed

# %% [markdown]
# ### Define timing of task
# The task's temporal structure is then defined, once as time steps and once as durations in milliseconds.
# Using a batch size larger than one aids the network in generalization, facilitating the solution to this task.
# The original number of iterations requires distributed computing.

# %%
n_batch = 1  # batch size, 1 in reference [2]
n_iter = 20  # number of iterations, 2000 in reference [2]
n_repeats = 500

steps = {
    "sequence": 750,  # time steps of one full sequence
}

steps["learning_window"] = steps["sequence"]  # time steps of window with non-zero learning signals
steps["task"] = n_iter * n_batch * steps["sequence"]  # time steps of task

steps.update(
    {
        "offset_gen": 1,  # offset since generator signals start from time step 1
        "delay_in_rec": 1,  # connection delay between input and recurrent neurons
        "delay_rec_out": 1,  # connection delay between recurrent and output neurons
        "delay_out_norm": 1,  # connection delay between output neurons for normalization
        "extension_sim": 1,  # extra time step to close right-open simulation time interval in Simulate()
    }
)

steps["delays"] = steps["delay_in_rec"] + steps["delay_rec_out"] + steps["delay_out_norm"]  # time steps of delays

steps["total_offset"] = steps["offset_gen"] + steps["delays"]  # time steps of total offset

steps["sim"] = steps["task"] + steps["total_offset"] + steps["extension_sim"]  # time steps of simulation

duration = {"step": 1.0}  # ms, temporal resolution of the simulation

duration.update({key: value * duration["step"] for key, value in steps.items()})  # ms, durations

# %% [markdown]
# ### Set up simulation
# As last step of the setup, we reset the NEST kernel to remove all existing NEST simulation settings and
# objects and set some NEST kernel parameters, some of which are e-prop-related.

# %%
params_setup = {
    "eprop_learning_window": 500,
    "eprop_reset_neurons_on_update": False,  # if True, reset dynamic variables at start of each update interval
    "eprop_update_interval": 500,  # ms, time interval for updating the synaptic weights
    "print_time": False,  # if True, print time progress bar during simulation, set False if run as code cell
    "resolution": duration["step"],
    "total_num_virtual_procs": 4,  # number of virtual processes, set in case of distributed computing
}

# %%
nest.ResetKernel()
nest.set(**params_setup)
# Out:
# Mar 05 13:43:42 correlation_detector [Info]:
#     Default for delta_tau changed from 0.5 to 5 ms
#
# Mar 05 13:43:42 correlomatrix_detector [Info]:
#     Default for delta_tau changed from 0.5 to 5 ms
#
# Mar 05 13:43:42 correlospinmatrix_detector [Info]:
#     Default for delta_tau changed from 0.1 to 1 ms
#
# Mar 05 13:43:42 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 1 ms.

# %% [markdown]
# ## Create neurons
# We proceed by creating a certain number of input, recurrent, and readout neurons and setting their parameters.
# Additionally, we already create an input spike generator and an output target rate generator, which we will
# configure later. Within the recurrent network, alongside a population of regular neurons, we introduce a
# population of adaptive neurons, to enhance the network's memory retention.

# %%
n_in = 12  # number of input neurons
n_ad = 128  # number of adaptive neurons
n_reg = 128  # number of regular neurons
n_rec = n_ad + n_reg  # number of recurrent neurons
n_out = 2  # number of readout neurons


params_nrn_reg = {
    "C_m": 1.0,  # pF, membrane capacitance - takes effect only if neurons get current input (here not the case)
    "c_reg": 2.0,  # firing rate regularization scaling - double the TF c_reg for technical reasons
    "E_L": 0.0,  # mV, leak / resting membrane potential
    "f_target": 10.0,  # spikes/s, target firing rate for firing rate regularization
    "gamma": 0.3,  # scaling of the pseudo derivative
    "I_e": 0.0,  # pA, external current input
    "regular_spike_arrival": True,  # If True, input spikes arrive at end of time step, if False at beginning
    "surrogate_gradient_function": "piecewise_linear",  # surrogate gradient / pseudo-derivative function
    "t_ref": 5.0,  # ms, duration of refractory period
    "tau_m": 20.0,  # ms, membrane time constant
    "V_m": 0.0,  # mV, initial value of the membrane voltage
    "V_th": 0.6,  # mV, spike threshold membrane voltage
}

params_nrn_ad = {
    "adapt_tau": 2000.0,  # ms, time constant of adaptive threshold
    "adaptation": 0.0,  # initial value of the spike threshold adaptation
    "C_m": 1.0,
    "c_reg": 2.0,
    "E_L": 0.0,
    "f_target": 10.0,
    "gamma": 0.3,
    "I_e": 0.0,
    "regular_spike_arrival": True,
    "surrogate_gradient_function": "piecewise_linear",
    "t_ref": 5.0,
    "tau_m": 20.0,
    "V_m": 0.0,
    "V_th": 0.6,
}

params_nrn_ad["adapt_beta"] = 1.7 * (
    (1.0 - np.exp(-duration["step"] / params_nrn_ad["adapt_tau"]))
    / (1.0 - np.exp(-duration["step"] / params_nrn_ad["tau_m"]))
)  # prefactor of adaptive threshold

params_nrn_out = {
    "C_m": 1.0,
    "E_L": 0.0,
    "I_e": 0.0,
    "loss": "mean_squared_error",  # loss function
    "regular_spike_arrival": False,
    "tau_m": 20.0,
    "V_m": 0.0,
}

# %%
# Intermediate parrot neurons required between input spike generators and recurrent neurons,
# since devices cannot establish plastic synapses for technical reasons

gen_spk_in = nest.Create("inhomogeneous_poisson_generator", n_in)
nrns_in = nest.Create("parrot_neuron", n_in)

# The suffix _bsshslm_2020 follows the NEST convention to indicate in the model name the paper
# that introduced it by the first letter of the authors' last names and the publication year.

nrns_reg = nest.Create("eprop_iaf_bsshslm_2020", n_reg, params_nrn_reg)
nrns_ad = nest.Create("eprop_iaf_adapt_bsshslm_2020", n_ad, params_nrn_ad)
nrns_out = nest.Create("eprop_readout_bsshslm_2020", n_out, params_nrn_out)
gen_rate_target = nest.Create("step_rate_generator", n_out)

nrns_rec = nrns_reg + nrns_ad

# %% [markdown]
# ## Create recorders
# We also create recorders, which, while not required for the training, will allow us to track various dynamic
# variables of the neurons, spikes, and changes in synaptic weights. To save computing time and memory, the
# recorders, the recorded variables, neurons, and synapses can be limited to the ones relevant to the
# experiment, and the recording interval can be increased (see the documentation on the specific recorders). By
# default, recordings are stored in memory but can also be written to file.

# %%
n_record = 1  # number of neurons per type to record dynamic variables from - this script requires n_record >= 1
n_record_w = 3  # number of senders and targets to record weights from - this script requires n_record_w >=1

if n_record == 0 or n_record_w == 0:
    raise ValueError("n_record and n_record_w >= 1 required")

params_mm_reg = {
    "interval": duration["step"],  # interval between two recorded time points
    "record_from": ["V_m", "surrogate_gradient", "learning_signal"],  # dynamic variables to record
    "start": duration["offset_gen"] + duration["delay_in_rec"],  # start time of recording
    "stop": duration["offset_gen"] + duration["delay_in_rec"] + duration["task"],  # stop time of recording
}

params_mm_ad = {
    "interval": duration["step"],
    "record_from": params_mm_reg["record_from"] + ["V_th_adapt", "adaptation"],
    "start": duration["offset_gen"] + duration["delay_in_rec"],
    "stop": duration["offset_gen"] + duration["delay_in_rec"] + duration["task"],
}

params_mm_out = {
    "interval": duration["step"],
    "record_from": ["V_m", "readout_signal", "readout_signal_unnorm", "target_signal", "error_signal"],
    "start": duration["total_offset"],
    "stop": duration["total_offset"] + duration["task"],
}

params_wr = {
    "senders": nrns_in[:n_record_w] + nrns_rec[:n_record_w],  # limit senders to subsample weights to record
    "targets": nrns_rec[:n_record_w] + nrns_out,  # limit targets to subsample weights to record from
    "start": duration["total_offset"],
    "stop": duration["total_offset"] + duration["task"],
}

params_sr = {
    "start": duration["total_offset"],
    "stop": duration["total_offset"] + duration["task"],
}

# %%
mm_reg = nest.Create("multimeter", params_mm_reg)
mm_ad = nest.Create("multimeter", params_mm_ad)
mm_out = nest.Create("multimeter", params_mm_out)
sr = nest.Create("spike_recorder", params_sr)
wr = nest.Create("weight_recorder", params_wr)

nrns_reg_record = nrns_reg[:n_record]
nrns_ad_record = nrns_ad[:n_record]

# %% [markdown]
# ## Create connections
# Now, we define the connectivity and set up the synaptic parameters, with the synaptic weights drawn from
# normal distributions. After these preparations, we establish the enumerated connections of the core network,
# as well as additional connections to the recorders.

# %%
params_conn_all_to_all = {"rule": "all_to_all", "allow_autapses": False}
params_conn_one_to_one = {"rule": "one_to_one"}


def calculate_glorot_dist(fan_in, fan_out):
    glorot_scale = 1.0 / max(1.0, (fan_in + fan_out) / 2.0)
    glorot_limit = np.sqrt(3.0 * glorot_scale)
    glorot_distribution = np.random.uniform(low=-glorot_limit, high=glorot_limit, size=(fan_in, fan_out))
    return glorot_distribution


dtype_weights = np.float32  # data type of weights - for reproducing TF results set to np.float32
weights_in_rec = np.array(np.random.randn(n_in, n_rec).T / np.sqrt(n_in), dtype=dtype_weights)
weights_rec_rec = np.array(np.random.randn(n_rec, n_rec).T / np.sqrt(n_rec), dtype=dtype_weights)
np.fill_diagonal(weights_rec_rec, 0.0)  # since no autapses set corresponding weights to zero
weights_rec_out = np.array(calculate_glorot_dist(n_rec, n_out).T, dtype=dtype_weights)
weights_out_rec = np.array(np.random.randn(n_rec, n_out), dtype=dtype_weights)

params_common_syn_eprop = {
    "optimizer": {
        "type": "adam",  # algorithm to optimize the weights
        "batch_size": n_batch,
        "beta_1": 0.9,  # exponential decay rate for 1st moment estimate of Adam optimizer
        "beta_2": 0.999,  # exponential decay rate for 2nd moment raw estimate of Adam optimizer
        "epsilon": 1e-8,  # small numerical stabilization constant of Adam optimizer
        "eta": 5e-3,  # learning rate
        "Wmin": -100.0,  # pA, minimal limit of the synaptic weights
        "Wmax": 100.0,  # pA, maximal limit of the synaptic weights
    },
    "average_gradient": True,  # if True, average the gradient over the learning window
    "weight_recorder": wr,
}

params_syn_base = {
    "synapse_model": "eprop_synapse_bsshslm_2020",
    "delay": duration["step"],  # ms, dendritic delay
    "tau_m_readout": params_nrn_out["tau_m"],  # ms, for technical reasons pass readout neuron membrane time constant
}

params_syn_in = params_syn_base.copy()
params_syn_in["weight"] = weights_in_rec  # pA, initial values for the synaptic weights

params_syn_rec = params_syn_base.copy()
params_syn_rec["weight"] = weights_rec_rec

params_syn_out = params_syn_base.copy()
params_syn_out["weight"] = weights_rec_out


params_syn_feedback = {
    "synapse_model": "eprop_learning_signal_connection_bsshslm_2020",
    "delay": duration["step"],
    "weight": weights_out_rec,
}

params_syn_out_out = {
    "synapse_model": "rate_connection_delayed",
    "delay": duration["step"],
    "receptor_type": 1,  # receptor type of readout neuron to receive other readout neuron's signals for softmax
    "weight": 1.0,  # pA, weight 1.0 required for correct softmax computation for technical reasons
}

params_syn_rate_target = {
    "synapse_model": "rate_connection_delayed",
    "delay": duration["step"],
    "receptor_type": 2,  # receptor type over which readout neuron receives target signal
}

params_syn_static = {
    "synapse_model": "static_synapse",
    "delay": duration["step"],
}

params_init_optimizer = {
    "optimizer": {
        "m": 0.0,  # initial 1st moment estimate m of Adam optimizer
        "v": 0.0,  # initial 2nd moment raw estimate v of Adam optimizer
    }
}

# %%
nest.SetDefaults("eprop_synapse_bsshslm_2020", params_common_syn_eprop)

nest.Connect(gen_spk_in, nrns_in, params_conn_one_to_one, params_syn_static)  # connection 1
nest.Connect(nrns_in, nrns_rec, params_conn_all_to_all, params_syn_in)  # connection 2
nest.Connect(nrns_rec, nrns_rec, params_conn_all_to_all, params_syn_rec)  # connection 3
nest.Connect(nrns_rec, nrns_out, params_conn_all_to_all, params_syn_out)  # connection 4
nest.Connect(nrns_out, nrns_rec, params_conn_all_to_all, params_syn_feedback)  # connection 5
nest.Connect(gen_rate_target, nrns_out, params_conn_one_to_one, params_syn_rate_target)  # connection 6
nest.Connect(nrns_out, nrns_out, params_conn_all_to_all, params_syn_out_out)  # connection 7

nest.Connect(nrns_in + nrns_rec, sr, params_conn_all_to_all, params_syn_static)

nest.Connect(mm_reg, nrns_reg_record, params_conn_all_to_all, params_syn_static)
nest.Connect(mm_ad, nrns_ad_record, params_conn_all_to_all, params_syn_static)
nest.Connect(mm_out, nrns_out, params_conn_all_to_all, params_syn_static)

# After creating the connections, we can individually initialize the optimizer's
# dynamic variables for single synapses (here exemplarily for two connections).

nest.GetConnections(nrns_rec[0], nrns_rec[1:3]).set([params_init_optimizer] * 2)

# %% [markdown]
# ## Create input and output
# We generate the input as four neuron populations, two producing the left and right cues, respectively, one the
# recall signal and one the background input throughout the task. The sequence of cues is drawn with a
# probability that favors one side. For each such sequence, the favored side, the solution or target, is
# assigned randomly to the left or right.

# %%
import pandas as pd
import random
import numpy as np

output_signal = []

def get_weights(pop_pre, pop_post):
    conns = nest.GetConnections(pop_pre, pop_post).get(["source", "target", "weight"])
    conns["senders"] = np.array(conns["source"]) - np.min(conns["source"])
    conns["targets"] = np.array(conns["target"]) - np.min(conns["target"])

    conns["weight_matrix"] = np.zeros((len(pop_post), len(pop_pre)))
    conns["weight_matrix"][conns["targets"], conns["senders"]] = conns["weight"]
    return conns

# Load DataFrames
sound_fet_1 = pd.read_csv("/home/harald_stabbetorp/Master/e-prop_master_nmbu/sound_fet/one_encoded_features.csv")
sound_fet_2 = pd.read_csv("/home/harald_stabbetorp/Master/e-prop_master_nmbu/sound_fet/two_encoded_features.csv")
silence = pd.read_csv("/home/harald_stabbetorp/Master/e-prop_master_nmbu/sound_fet/zeros.csv")

pca = PCA(n_components=12)
sound_fet_1_pca = pca.fit_transform(sound_fet_1).T
sound_fet_2_pca = pca.fit_transform(sound_fet_2).T
silence_pca = pca.fit_transform(silence).T

# Dictionary for easy access
df_dict = {"sound_fet_1": sound_fet_1_pca, "sound_fet_2": sound_fet_2_pca, "silence": silence_pca}

previous_max_time = 0  # Initialize time tracker

weights_pre_train = {
    "in_rec": get_weights(nrns_in, nrns_rec),
    "rec_rec": get_weights(nrns_rec, nrns_rec),
    "rec_out": get_weights(nrns_rec, nrns_out),
    }

for _ in range(n_repeats):
    # Shuffle DataFrames
    df_names = ["sound_fet_1"] * 10 + ["sound_fet_2"] * 10 + ["silence"] * 10 
    random.shuffle(df_names)

    # Stack data
    stacked_dfs = pd.DataFrame(np.hstack([df_dict[name] for name in df_names]))
    scaler = MinMaxScaler(feature_range=(-500, 500))
    stacked_df_scale = scaler.fit_transform(stacked_dfs)

    # Time-related parameters
    sequence_starts = np.arange(0.0, duration["task"], duration["sequence"]) + duration["offset_gen"]

    params_gen_spk_in = [None] * stacked_dfs.shape[0]  

    for neuron_idx in range(stacked_dfs.shape[0]):  
        input_value = stacked_dfs[neuron_idx]  

        time_indices = np.arange(0.0, duration["sequence"], duration["step"])[:input_value.shape[0]]

        # Adjust time indices by previous max time
        input_spike_times_all = np.hstack([time_indices + start for start in sequence_starts]) + previous_max_time

        spike_values = np.tile(input_value, len(sequence_starts)).astype(np.float32)

        params_gen_spk_in[neuron_idx] = {
            "rate_times": input_spike_times_all.astype(np.float32),
            "rate_values": spike_values
        }
    # Set spike generators
    nest.SetStatus(gen_spk_in, params_gen_spk_in)


    # create a target list for the readout neurons
    # Convert list_data to 1s and 2s
    binary_array = np.array([1. if item == "sound_fet_1" else 2. if item == "sound_fet_2" else 0. for item in df_names])

    # Repeat each value 25 times
    final_array = np.repeat(binary_array, 25)

    # Define the number of time steps per sequence
    num_time_steps = steps["sequence"]

    # Create target signal
    target_signal = final_array

    # Make the target signal repeat 5 times
    target_signal = np.tile(target_signal, n_iter)

    # Compute the total number of time steps in the entire task duration
    total_time_steps = int(duration["task"] / duration["step"])

    # Compute how many times to tile `target_signal`
    num_repeats = total_time_steps // num_time_steps  # Ensure the length is correct

    # Generate the amplitude values
    amplitude_values = np.tile(target_signal, num_repeats).astype(np.float32)

    # Generate time points for amplitude changes
    amplitude_times = np.arange(0.0, duration["task"], duration["step"]) + duration["total_offset"]

    # Append the target signal to the params_gen_rate_target list
    params_gen_rate_target = []

    for num in range(1,3):
        num_values = np.where(target_signal==num, 1., 0.)
        params_gen_rate_target.append({
            "amplitude_times": amplitude_times.astype(np.float32),
            "amplitude_values": num_values,
        })

    # Set the target signal
    nest.SetStatus(gen_rate_target, params_gen_rate_target)

    gen_spk_final_update = nest.Create("spike_generator", 1, {"spike_times": [duration["task"] + duration["delays"]]})

    nest.Connect(gen_spk_final_update, nrns_in + nrns_rec, "all_to_all", {"weight": 1000.0})

    nest.Simulate(duration["sim"])
    output_signal.append(mm_out.get("events"))
    kernel_status = nest.GetKernelStatus()
    # Update the previous max time for the next iteration
    previous_max_time = (kernel_status['biological_time'])
    print(f"Repeat {_+1} of {n_repeats} done")
# Out:
# /home/harald_stabbetorp/Master/.venv/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:789: RuntimeWarning:invalid value encountered in divide
# Mar 05 13:43:43 ConnectionManager [Warning]:
#     New connections created, connection descriptors previously obtained using
#     'GetConnections' are now invalid.
#
# Mar 05 13:43:43 NodeManager::prepare_nodes [Info]:
#     Preparing 350 nodes for simulation.
#
# Mar 05 13:43:43 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 350
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:45 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:45 NodeManager::prepare_nodes [Info]:
#     Preparing 354 nodes for simulation.
#
# Mar 05 13:43:45 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 354
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:46 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:46 NodeManager::prepare_nodes [Info]:
#     Preparing 358 nodes for simulation.
#
# Mar 05 13:43:46 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 358
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:46 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:46 NodeManager::prepare_nodes [Info]:
#     Preparing 362 nodes for simulation.
#
# Mar 05 13:43:46 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 362
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:49 NodeManager::prepare_nodes [Info]:
#     Preparing 366 nodes for simulation.
#
# Mar 05 13:43:49 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 366
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:50 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:50 NodeManager::prepare_nodes [Info]:
#     Preparing 370 nodes for simulation.
#
# Mar 05 13:43:50 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 370
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:52 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:52 NodeManager::prepare_nodes [Info]:
#     Preparing 374 nodes for simulation.
#
# Mar 05 13:43:52 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 374
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:53 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:53 NodeManager::prepare_nodes [Info]:
#     Preparing 378 nodes for simulation.
#
# Mar 05 13:43:53 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 378
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:55 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:55 NodeManager::prepare_nodes [Info]:
#     Preparing 382 nodes for simulation.
#
# Mar 05 13:43:55 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 382
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:56 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:56 NodeManager::prepare_nodes [Info]:
#     Preparing 386 nodes for simulation.
#
# Mar 05 13:43:56 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 386
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:58 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:58 NodeManager::prepare_nodes [Info]:
#     Preparing 390 nodes for simulation.
#
# Mar 05 13:43:58 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 390
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:57 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:57 NodeManager::prepare_nodes [Info]:
#     Preparing 394 nodes for simulation.
#
# Mar 05 13:43:57 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 394
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:43:58 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:43:58 NodeManager::prepare_nodes [Info]:
#     Preparing 398 nodes for simulation.
#
# Mar 05 13:43:58 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 398
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:00 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:00 NodeManager::prepare_nodes [Info]:
#     Preparing 402 nodes for simulation.
#
# Mar 05 13:44:00 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 402
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:01 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:01 NodeManager::prepare_nodes [Info]:
#     Preparing 406 nodes for simulation.
#
# Mar 05 13:44:01 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 406
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:03 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:03 NodeManager::prepare_nodes [Info]:
#     Preparing 410 nodes for simulation.
#
# Mar 05 13:44:03 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 410
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:03 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:03 NodeManager::prepare_nodes [Info]:
#     Preparing 414 nodes for simulation.
#
# Mar 05 13:44:03 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 414
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:05 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:05 NodeManager::prepare_nodes [Info]:
#     Preparing 418 nodes for simulation.
#
# Mar 05 13:44:05 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 418
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:07 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:07 NodeManager::prepare_nodes [Info]:
#     Preparing 422 nodes for simulation.
#
# Mar 05 13:44:07 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 422
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:09 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:09 NodeManager::prepare_nodes [Info]:
#     Preparing 426 nodes for simulation.
#
# Mar 05 13:44:09 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 426
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:10 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:10 NodeManager::prepare_nodes [Info]:
#     Preparing 430 nodes for simulation.
#
# Mar 05 13:44:10 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 430
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:12 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:12 NodeManager::prepare_nodes [Info]:
#     Preparing 434 nodes for simulation.
#
# Mar 05 13:44:12 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 434
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:13 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:13 NodeManager::prepare_nodes [Info]:
#     Preparing 438 nodes for simulation.
#
# Mar 05 13:44:13 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 438
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:15 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:15 NodeManager::prepare_nodes [Info]:
#     Preparing 442 nodes for simulation.
#
# Mar 05 13:44:15 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 442
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:17 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:17 NodeManager::prepare_nodes [Info]:
#     Preparing 446 nodes for simulation.
#
# Mar 05 13:44:17 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 446
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:18 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:18 NodeManager::prepare_nodes [Info]:
#     Preparing 450 nodes for simulation.
#
# Mar 05 13:44:18 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 450
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:20 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:20 NodeManager::prepare_nodes [Info]:
#     Preparing 454 nodes for simulation.
#
# Mar 05 13:44:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 454
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:22 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:22 NodeManager::prepare_nodes [Info]:
#     Preparing 458 nodes for simulation.
#
# Mar 05 13:44:22 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 458
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:24 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:24 NodeManager::prepare_nodes [Info]:
#     Preparing 462 nodes for simulation.
#
# Mar 05 13:44:24 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 462
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:26 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:26 NodeManager::prepare_nodes [Info]:
#     Preparing 466 nodes for simulation.
#
# Mar 05 13:44:26 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 466
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:28 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:28 NodeManager::prepare_nodes [Info]:
#     Preparing 470 nodes for simulation.
#
# Mar 05 13:44:28 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 470
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:28 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:28 NodeManager::prepare_nodes [Info]:
#     Preparing 474 nodes for simulation.
#
# Mar 05 13:44:28 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 474
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:29 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:29 NodeManager::prepare_nodes [Info]:
#     Preparing 478 nodes for simulation.
#
# Mar 05 13:44:29 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 478
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:30 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:30 NodeManager::prepare_nodes [Info]:
#     Preparing 482 nodes for simulation.
#
# Mar 05 13:44:30 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 482
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:32 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:32 NodeManager::prepare_nodes [Info]:
#     Preparing 486 nodes for simulation.
#
# Mar 05 13:44:32 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 486
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:34 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:34 NodeManager::prepare_nodes [Info]:
#     Preparing 490 nodes for simulation.
#
# Mar 05 13:44:34 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 490
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:35 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:35 NodeManager::prepare_nodes [Info]:
#     Preparing 494 nodes for simulation.
#
# Mar 05 13:44:35 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 494
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:37 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:37 NodeManager::prepare_nodes [Info]:
#     Preparing 498 nodes for simulation.
#
# Mar 05 13:44:37 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 498
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:39 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:39 NodeManager::prepare_nodes [Info]:
#     Preparing 502 nodes for simulation.
#
# Mar 05 13:44:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 502
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:41 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:41 NodeManager::prepare_nodes [Info]:
#     Preparing 506 nodes for simulation.
#
# Mar 05 13:44:41 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 506
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:43 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:43 NodeManager::prepare_nodes [Info]:
#     Preparing 510 nodes for simulation.
#
# Mar 05 13:44:43 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 510
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:45 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:45 NodeManager::prepare_nodes [Info]:
#     Preparing 514 nodes for simulation.
#
# Mar 05 13:44:45 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 514
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:47 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:47 NodeManager::prepare_nodes [Info]:
#     Preparing 518 nodes for simulation.
#
# Mar 05 13:44:47 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 518
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:49 NodeManager::prepare_nodes [Info]:
#     Preparing 522 nodes for simulation.
#
# Mar 05 13:44:49 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 522
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:50 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:50 NodeManager::prepare_nodes [Info]:
#     Preparing 526 nodes for simulation.
#
# Mar 05 13:44:50 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 526
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:52 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:52 NodeManager::prepare_nodes [Info]:
#     Preparing 530 nodes for simulation.
#
# Mar 05 13:44:52 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 530
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:53 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:53 NodeManager::prepare_nodes [Info]:
#     Preparing 534 nodes for simulation.
#
# Mar 05 13:44:53 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 534
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:55 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:55 NodeManager::prepare_nodes [Info]:
#     Preparing 538 nodes for simulation.
#
# Mar 05 13:44:55 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 538
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:57 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:57 NodeManager::prepare_nodes [Info]:
#     Preparing 542 nodes for simulation.
#
# Mar 05 13:44:57 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 542
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:58 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:58 NodeManager::prepare_nodes [Info]:
#     Preparing 546 nodes for simulation.
#
# Mar 05 13:44:58 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 546
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:57 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:57 NodeManager::prepare_nodes [Info]:
#     Preparing 550 nodes for simulation.
#
# Mar 05 13:44:57 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 550
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:44:59 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:44:59 NodeManager::prepare_nodes [Info]:
#     Preparing 554 nodes for simulation.
#
# Mar 05 13:44:59 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 554
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:01 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:01 NodeManager::prepare_nodes [Info]:
#     Preparing 558 nodes for simulation.
#
# Mar 05 13:45:01 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 558
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:02 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:02 NodeManager::prepare_nodes [Info]:
#     Preparing 562 nodes for simulation.
#
# Mar 05 13:45:02 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 562
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:04 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:04 NodeManager::prepare_nodes [Info]:
#     Preparing 566 nodes for simulation.
#
# Mar 05 13:45:04 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 566
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:06 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:06 NodeManager::prepare_nodes [Info]:
#     Preparing 570 nodes for simulation.
#
# Mar 05 13:45:06 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 570
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:07 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:07 NodeManager::prepare_nodes [Info]:
#     Preparing 574 nodes for simulation.
#
# Mar 05 13:45:07 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 574
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:09 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:09 NodeManager::prepare_nodes [Info]:
#     Preparing 578 nodes for simulation.
#
# Mar 05 13:45:09 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 578
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:11 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:11 NodeManager::prepare_nodes [Info]:
#     Preparing 582 nodes for simulation.
#
# Mar 05 13:45:11 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 582
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:13 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:13 NodeManager::prepare_nodes [Info]:
#     Preparing 586 nodes for simulation.
#
# Mar 05 13:45:13 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 586
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:15 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:15 NodeManager::prepare_nodes [Info]:
#     Preparing 590 nodes for simulation.
#
# Mar 05 13:45:15 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 590
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:17 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:17 NodeManager::prepare_nodes [Info]:
#     Preparing 594 nodes for simulation.
#
# Mar 05 13:45:17 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 594
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:18 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:18 NodeManager::prepare_nodes [Info]:
#     Preparing 598 nodes for simulation.
#
# Mar 05 13:45:18 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 598
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:21 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:21 NodeManager::prepare_nodes [Info]:
#     Preparing 602 nodes for simulation.
#
# Mar 05 13:45:21 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 602
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:23 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:23 NodeManager::prepare_nodes [Info]:
#     Preparing 606 nodes for simulation.
#
# Mar 05 13:45:23 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 606
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:24 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:24 NodeManager::prepare_nodes [Info]:
#     Preparing 610 nodes for simulation.
#
# Mar 05 13:45:24 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 610
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:25 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:25 NodeManager::prepare_nodes [Info]:
#     Preparing 614 nodes for simulation.
#
# Mar 05 13:45:25 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 614
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:27 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:27 NodeManager::prepare_nodes [Info]:
#     Preparing 618 nodes for simulation.
#
# Mar 05 13:45:27 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 618
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:28 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:28 NodeManager::prepare_nodes [Info]:
#     Preparing 622 nodes for simulation.
#
# Mar 05 13:45:28 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 622
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:30 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:30 NodeManager::prepare_nodes [Info]:
#     Preparing 626 nodes for simulation.
#
# Mar 05 13:45:30 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 626
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:33 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:33 NodeManager::prepare_nodes [Info]:
#     Preparing 630 nodes for simulation.
#
# Mar 05 13:45:33 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 630
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:35 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:35 NodeManager::prepare_nodes [Info]:
#     Preparing 634 nodes for simulation.
#
# Mar 05 13:45:35 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 634
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:36 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:36 NodeManager::prepare_nodes [Info]:
#     Preparing 638 nodes for simulation.
#
# Mar 05 13:45:36 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 638
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:37 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:37 NodeManager::prepare_nodes [Info]:
#     Preparing 642 nodes for simulation.
#
# Mar 05 13:45:37 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 642
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:40 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:40 NodeManager::prepare_nodes [Info]:
#     Preparing 646 nodes for simulation.
#
# Mar 05 13:45:40 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 646
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:42 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:42 NodeManager::prepare_nodes [Info]:
#     Preparing 650 nodes for simulation.
#
# Mar 05 13:45:42 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 650
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:44 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:44 NodeManager::prepare_nodes [Info]:
#     Preparing 654 nodes for simulation.
#
# Mar 05 13:45:44 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 654
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:47 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:47 NodeManager::prepare_nodes [Info]:
#     Preparing 658 nodes for simulation.
#
# Mar 05 13:45:47 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 658
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:48 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:48 NodeManager::prepare_nodes [Info]:
#     Preparing 662 nodes for simulation.
#
# Mar 05 13:45:48 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 662
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:49 NodeManager::prepare_nodes [Info]:
#     Preparing 666 nodes for simulation.
#
# Mar 05 13:45:49 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 666
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:51 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:51 NodeManager::prepare_nodes [Info]:
#     Preparing 670 nodes for simulation.
#
# Mar 05 13:45:51 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 670
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:54 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:54 NodeManager::prepare_nodes [Info]:
#     Preparing 674 nodes for simulation.
#
# Mar 05 13:45:54 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 674
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:57 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:57 NodeManager::prepare_nodes [Info]:
#     Preparing 678 nodes for simulation.
#
# Mar 05 13:45:57 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 678
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:45:59 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:45:59 NodeManager::prepare_nodes [Info]:
#     Preparing 682 nodes for simulation.
#
# Mar 05 13:45:59 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 682
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:00 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:00 NodeManager::prepare_nodes [Info]:
#     Preparing 686 nodes for simulation.
#
# Mar 05 13:46:00 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 686
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:02 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:02 NodeManager::prepare_nodes [Info]:
#     Preparing 690 nodes for simulation.
#
# Mar 05 13:46:02 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 690
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:03 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:03 NodeManager::prepare_nodes [Info]:
#     Preparing 694 nodes for simulation.
#
# Mar 05 13:46:03 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 694
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:06 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:06 NodeManager::prepare_nodes [Info]:
#     Preparing 698 nodes for simulation.
#
# Mar 05 13:46:06 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 698
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:08 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:08 NodeManager::prepare_nodes [Info]:
#     Preparing 702 nodes for simulation.
#
# Mar 05 13:46:08 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 702
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:11 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:11 NodeManager::prepare_nodes [Info]:
#     Preparing 706 nodes for simulation.
#
# Mar 05 13:46:11 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 706
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:12 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:12 NodeManager::prepare_nodes [Info]:
#     Preparing 710 nodes for simulation.
#
# Mar 05 13:46:12 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 710
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:15 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:15 NodeManager::prepare_nodes [Info]:
#     Preparing 714 nodes for simulation.
#
# Mar 05 13:46:15 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 714
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:17 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:17 NodeManager::prepare_nodes [Info]:
#     Preparing 718 nodes for simulation.
#
# Mar 05 13:46:17 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 718
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:20 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:20 NodeManager::prepare_nodes [Info]:
#     Preparing 722 nodes for simulation.
#
# Mar 05 13:46:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 722
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:23 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:23 NodeManager::prepare_nodes [Info]:
#     Preparing 726 nodes for simulation.
#
# Mar 05 13:46:23 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 726
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:26 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:26 NodeManager::prepare_nodes [Info]:
#     Preparing 730 nodes for simulation.
#
# Mar 05 13:46:26 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 730
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:28 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:28 NodeManager::prepare_nodes [Info]:
#     Preparing 734 nodes for simulation.
#
# Mar 05 13:46:28 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 734
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:30 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:30 NodeManager::prepare_nodes [Info]:
#     Preparing 738 nodes for simulation.
#
# Mar 05 13:46:30 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 738
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:31 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:31 NodeManager::prepare_nodes [Info]:
#     Preparing 742 nodes for simulation.
#
# Mar 05 13:46:31 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 742
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:33 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:33 NodeManager::prepare_nodes [Info]:
#     Preparing 746 nodes for simulation.
#
# Mar 05 13:46:33 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 746
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:35 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:35 NodeManager::prepare_nodes [Info]:
#     Preparing 750 nodes for simulation.
#
# Mar 05 13:46:35 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 750
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:36 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:36 NodeManager::prepare_nodes [Info]:
#     Preparing 754 nodes for simulation.
#
# Mar 05 13:46:36 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 754
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:39 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:39 NodeManager::prepare_nodes [Info]:
#     Preparing 758 nodes for simulation.
#
# Mar 05 13:46:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 758
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:42 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:42 NodeManager::prepare_nodes [Info]:
#     Preparing 762 nodes for simulation.
#
# Mar 05 13:46:42 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 762
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:45 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:45 NodeManager::prepare_nodes [Info]:
#     Preparing 766 nodes for simulation.
#
# Mar 05 13:46:45 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 766
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:49 NodeManager::prepare_nodes [Info]:
#     Preparing 770 nodes for simulation.
#
# Mar 05 13:46:49 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 770
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:52 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:52 NodeManager::prepare_nodes [Info]:
#     Preparing 774 nodes for simulation.
#
# Mar 05 13:46:52 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 774
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:54 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:55 NodeManager::prepare_nodes [Info]:
#     Preparing 778 nodes for simulation.
#
# Mar 05 13:46:55 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 778
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:57 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:57 NodeManager::prepare_nodes [Info]:
#     Preparing 782 nodes for simulation.
#
# Mar 05 13:46:57 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 782
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:46:59 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:46:59 NodeManager::prepare_nodes [Info]:
#     Preparing 786 nodes for simulation.
#
# Mar 05 13:46:59 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 786
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:02 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:02 NodeManager::prepare_nodes [Info]:
#     Preparing 790 nodes for simulation.
#
# Mar 05 13:47:02 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 790
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:04 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:04 NodeManager::prepare_nodes [Info]:
#     Preparing 794 nodes for simulation.
#
# Mar 05 13:47:04 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 794
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:07 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:07 NodeManager::prepare_nodes [Info]:
#     Preparing 798 nodes for simulation.
#
# Mar 05 13:47:07 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 798
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:10 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:10 NodeManager::prepare_nodes [Info]:
#     Preparing 802 nodes for simulation.
#
# Mar 05 13:47:10 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 802
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:13 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:13 NodeManager::prepare_nodes [Info]:
#     Preparing 806 nodes for simulation.
#
# Mar 05 13:47:13 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 806
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:15 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:16 NodeManager::prepare_nodes [Info]:
#     Preparing 810 nodes for simulation.
#
# Mar 05 13:47:16 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 810
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:18 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:18 NodeManager::prepare_nodes [Info]:
#     Preparing 814 nodes for simulation.
#
# Mar 05 13:47:18 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 814
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:21 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:21 NodeManager::prepare_nodes [Info]:
#     Preparing 818 nodes for simulation.
#
# Mar 05 13:47:21 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 818
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:25 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:25 NodeManager::prepare_nodes [Info]:
#     Preparing 822 nodes for simulation.
#
# Mar 05 13:47:25 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 822
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:27 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:27 NodeManager::prepare_nodes [Info]:
#     Preparing 826 nodes for simulation.
#
# Mar 05 13:47:27 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 826
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:31 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:31 NodeManager::prepare_nodes [Info]:
#     Preparing 830 nodes for simulation.
#
# Mar 05 13:47:31 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 830
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:31 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:31 NodeManager::prepare_nodes [Info]:
#     Preparing 834 nodes for simulation.
#
# Mar 05 13:47:31 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 834
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:34 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:34 NodeManager::prepare_nodes [Info]:
#     Preparing 838 nodes for simulation.
#
# Mar 05 13:47:34 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 838
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:37 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:37 NodeManager::prepare_nodes [Info]:
#     Preparing 842 nodes for simulation.
#
# Mar 05 13:47:37 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 842
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:40 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:40 NodeManager::prepare_nodes [Info]:
#     Preparing 846 nodes for simulation.
#
# Mar 05 13:47:40 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 846
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:43 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:43 NodeManager::prepare_nodes [Info]:
#     Preparing 850 nodes for simulation.
#
# Mar 05 13:47:43 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 850
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:46 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:46 NodeManager::prepare_nodes [Info]:
#     Preparing 854 nodes for simulation.
#
# Mar 05 13:47:46 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 854
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:49 NodeManager::prepare_nodes [Info]:
#     Preparing 858 nodes for simulation.
#
# Mar 05 13:47:49 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 858
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:52 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:52 NodeManager::prepare_nodes [Info]:
#     Preparing 862 nodes for simulation.
#
# Mar 05 13:47:52 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 862
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:55 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:55 NodeManager::prepare_nodes [Info]:
#     Preparing 866 nodes for simulation.
#
# Mar 05 13:47:55 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 866
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:58 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:58 NodeManager::prepare_nodes [Info]:
#     Preparing 870 nodes for simulation.
#
# Mar 05 13:47:58 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 870
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:47:59 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:47:59 NodeManager::prepare_nodes [Info]:
#     Preparing 874 nodes for simulation.
#
# Mar 05 13:47:59 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 874
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:48:01 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:48:01 NodeManager::prepare_nodes [Info]:
#     Preparing 878 nodes for simulation.
#
# Mar 05 13:48:01 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 878
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:48:04 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:48:04 NodeManager::prepare_nodes [Info]:
#     Preparing 882 nodes for simulation.
#
# Mar 05 13:48:04 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 882
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 13:48:07 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 13:48:07 NodeManager::prepare_nodes [Info]:
#     Preparing 886 nodes for simulation.
#
# Mar 05 13:48:07 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 886
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
# ...
#     Preparing 2170 nodes for simulation.
#
# Mar 05 14:09:51 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2170
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:09:56 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:09:56 NodeManager::prepare_nodes [Info]:
#     Preparing 2174 nodes for simulation.
#
# Mar 05 14:09:56 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2174
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:01 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:01 NodeManager::prepare_nodes [Info]:
#     Preparing 2178 nodes for simulation.
#
# Mar 05 14:10:01 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2178
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:05 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:06 NodeManager::prepare_nodes [Info]:
#     Preparing 2182 nodes for simulation.
#
# Mar 05 14:10:06 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2182
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:10 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:10 NodeManager::prepare_nodes [Info]:
#     Preparing 2186 nodes for simulation.
#
# Mar 05 14:10:10 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2186
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:15 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:15 NodeManager::prepare_nodes [Info]:
#     Preparing 2190 nodes for simulation.
#
# Mar 05 14:10:15 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2190
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:20 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:20 NodeManager::prepare_nodes [Info]:
#     Preparing 2194 nodes for simulation.
#
# Mar 05 14:10:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2194
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:23 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:23 NodeManager::prepare_nodes [Info]:
#     Preparing 2198 nodes for simulation.
#
# Mar 05 14:10:23 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2198
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:28 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:29 NodeManager::prepare_nodes [Info]:
#     Preparing 2202 nodes for simulation.
#
# Mar 05 14:10:29 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2202
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:34 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:34 NodeManager::prepare_nodes [Info]:
#     Preparing 2206 nodes for simulation.
#
# Mar 05 14:10:34 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2206
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:39 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:39 NodeManager::prepare_nodes [Info]:
#     Preparing 2210 nodes for simulation.
#
# Mar 05 14:10:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2210
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:44 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:44 NodeManager::prepare_nodes [Info]:
#     Preparing 2214 nodes for simulation.
#
# Mar 05 14:10:44 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2214
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:49 NodeManager::prepare_nodes [Info]:
#     Preparing 2218 nodes for simulation.
#
# Mar 05 14:10:49 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2218
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:52 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:52 NodeManager::prepare_nodes [Info]:
#     Preparing 2222 nodes for simulation.
#
# Mar 05 14:10:52 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2222
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:10:57 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:10:57 NodeManager::prepare_nodes [Info]:
#     Preparing 2226 nodes for simulation.
#
# Mar 05 14:10:57 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2226
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:02 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:02 NodeManager::prepare_nodes [Info]:
#     Preparing 2230 nodes for simulation.
#
# Mar 05 14:11:02 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2230
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:07 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:07 NodeManager::prepare_nodes [Info]:
#     Preparing 2234 nodes for simulation.
#
# Mar 05 14:11:07 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2234
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:12 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:12 NodeManager::prepare_nodes [Info]:
#     Preparing 2238 nodes for simulation.
#
# Mar 05 14:11:12 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2238
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:17 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:17 NodeManager::prepare_nodes [Info]:
#     Preparing 2242 nodes for simulation.
#
# Mar 05 14:11:17 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2242
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:22 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:22 NodeManager::prepare_nodes [Info]:
#     Preparing 2246 nodes for simulation.
#
# Mar 05 14:11:22 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2246
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:25 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:25 NodeManager::prepare_nodes [Info]:
#     Preparing 2250 nodes for simulation.
#
# Mar 05 14:11:25 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2250
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:30 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:30 NodeManager::prepare_nodes [Info]:
#     Preparing 2254 nodes for simulation.
#
# Mar 05 14:11:30 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2254
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:35 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:36 NodeManager::prepare_nodes [Info]:
#     Preparing 2258 nodes for simulation.
#
# Mar 05 14:11:36 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2258
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:41 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:41 NodeManager::prepare_nodes [Info]:
#     Preparing 2262 nodes for simulation.
#
# Mar 05 14:11:41 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2262
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:46 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:46 NodeManager::prepare_nodes [Info]:
#     Preparing 2266 nodes for simulation.
#
# Mar 05 14:11:46 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2266
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:51 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:51 NodeManager::prepare_nodes [Info]:
#     Preparing 2270 nodes for simulation.
#
# Mar 05 14:11:51 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2270
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:54 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:54 NodeManager::prepare_nodes [Info]:
#     Preparing 2274 nodes for simulation.
#
# Mar 05 14:11:54 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2274
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:11:59 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:11:59 NodeManager::prepare_nodes [Info]:
#     Preparing 2278 nodes for simulation.
#
# Mar 05 14:11:59 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2278
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:04 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:04 NodeManager::prepare_nodes [Info]:
#     Preparing 2282 nodes for simulation.
#
# Mar 05 14:12:04 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2282
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:08 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:09 NodeManager::prepare_nodes [Info]:
#     Preparing 2286 nodes for simulation.
#
# Mar 05 14:12:09 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2286
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:14 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:14 NodeManager::prepare_nodes [Info]:
#     Preparing 2290 nodes for simulation.
#
# Mar 05 14:12:14 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2290
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:19 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:19 NodeManager::prepare_nodes [Info]:
#     Preparing 2294 nodes for simulation.
#
# Mar 05 14:12:19 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2294
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:24 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:24 NodeManager::prepare_nodes [Info]:
#     Preparing 2298 nodes for simulation.
#
# Mar 05 14:12:24 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2298
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:28 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:28 NodeManager::prepare_nodes [Info]:
#     Preparing 2302 nodes for simulation.
#
# Mar 05 14:12:28 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2302
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:33 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:33 NodeManager::prepare_nodes [Info]:
#     Preparing 2306 nodes for simulation.
#
# Mar 05 14:12:33 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2306
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:38 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:38 NodeManager::prepare_nodes [Info]:
#     Preparing 2310 nodes for simulation.
#
# Mar 05 14:12:38 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2310
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:43 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:43 NodeManager::prepare_nodes [Info]:
#     Preparing 2314 nodes for simulation.
#
# Mar 05 14:12:43 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2314
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:48 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:48 NodeManager::prepare_nodes [Info]:
#     Preparing 2318 nodes for simulation.
#
# Mar 05 14:12:48 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2318
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:53 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:53 NodeManager::prepare_nodes [Info]:
#     Preparing 2322 nodes for simulation.
#
# Mar 05 14:12:53 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2322
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:12:57 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:12:57 NodeManager::prepare_nodes [Info]:
#     Preparing 2326 nodes for simulation.
#
# Mar 05 14:12:57 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2326
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:13:02 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:13:03 NodeManager::prepare_nodes [Info]:
#     Preparing 2330 nodes for simulation.
#
# Mar 05 14:13:03 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2330
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:13:08 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:13:08 NodeManager::prepare_nodes [Info]:
#     Preparing 2334 nodes for simulation.
#
# Mar 05 14:13:08 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2334
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:13:13 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:13:13 NodeManager::prepare_nodes [Info]:
#     Preparing 2338 nodes for simulation.
#
# Mar 05 14:13:13 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2338
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:13:18 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:13:18 NodeManager::prepare_nodes [Info]:
#     Preparing 2342 nodes for simulation.
#
# Mar 05 14:13:18 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2342
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:13:24 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 05 14:13:24 NodeManager::prepare_nodes [Info]:
#     Preparing 2346 nodes for simulation.
#
# Mar 05 14:13:24 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2346
#     Simulation time (ms): 15005
#     Number of OpenMP threads: 4
#     Number of MPI processes: 1
#
# Mar 05 14:13:29 SimulationManager::run [Info]:
#     Simulation finished.

# %% [markdown]
# ## Read out post-training weights
# After the training, we can read out the optimized final weights.

# %%
weights_post_train = {
    "in_rec": get_weights(nrns_in, nrns_rec),
    "rec_rec": get_weights(nrns_rec, nrns_rec),
    "rec_out": get_weights(nrns_rec, nrns_out),
}

# %% [markdown]
# ## Read out recorders
# We can also retrieve the recorded history of the dynamic variables and weights, as well as detected spikes.

# %%
events_mm_reg = mm_reg.get("events")
events_mm_ad = mm_ad.get("events")
events_mm_out = mm_out.get("events")
events_sr = sr.get("events")
events_wr = wr.get("events")

# %% [markdown]
# ## Evaluate training error
# We evaluate the network's training error by calculating a loss - in this case, the cross-entropy error between
# the integrated recurrent network activity and the target rate.

# %%
readout_signal = output_signal[-1]["readout_signal"]  # corresponds to softmax
target_signal = output_signal[-1]["target_signal"]
senders = output_signal[-1]["senders"]

readout_signal = np.array([readout_signal[senders == i] for i in set(senders)])
target_signal = np.array([target_signal[senders == i] for i in set(senders)])

readout_signal = readout_signal.reshape((n_out, n_iter, n_batch, steps["sequence"]))
readout_signal = readout_signal[:, :, :, -steps["learning_window"] :]

target_signal = target_signal.reshape((n_out, n_iter, n_batch, steps["sequence"]))
target_signal = target_signal[:, :, :, -steps["learning_window"] :]

loss = -np.mean(np.sum(target_signal * np.log(readout_signal), axis=0), axis=(1, 2))

y_prediction = np.argmax(np.mean(readout_signal, axis=3), axis=0)
y_target = np.argmax(np.mean(target_signal, axis=3), axis=0)
accuracy = np.mean((y_target == y_prediction), axis=1)
recall_errors = 1.0 - accuracy
# Out:
# /tmp/ipykernel_786807/112542710.py:14: RuntimeWarning:divide by zero encountered in log
# /tmp/ipykernel_786807/112542710.py:14: RuntimeWarning:invalid value encountered in log
# /tmp/ipykernel_786807/112542710.py:14: RuntimeWarning:invalid value encountered in multiply

# %%
#print(readout_signal)
print(readout_signal[0])
# Out:
# [[[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -1.79036895e-04
#    -1.70305163e-04 -1.61999282e-04]]
#
#  [[-1.54098484e-04 -1.46583012e-04 -1.60676995e-04 ... -1.14532435e-05
#    -1.08946623e-05 -1.03633233e-05]]
#
#  [[-9.85789806e-06 -9.37712270e-06 -8.91979503e-06 ... -4.30658719e-15
#    -4.09655245e-15 -3.89676123e-15]]
#
#  ...
#
#  [[ 2.80854965e-01  2.85809233e-01  2.80859610e-01 ...  2.97181531e-01
#     3.15385685e-01  3.25947719e-01]]
#
#  [[ 3.11717042e-01  3.22981276e-01  3.06109145e-01 ...  1.60996404e-02
#     1.53144516e-02  1.45675570e-02]]
#
#  [[ 1.38570889e-02  1.31812707e-02  1.25384125e-02 ...  3.81631607e-01
#     3.65026373e-01  3.81983215e-01]]]

# %% [markdown]
# ## Plot results
# Then, we plot a series of plots.

# %%
do_plotting = True  # if True, plot the results

if not do_plotting:
    exit()

colors = {
    "blue": "#2854c5ff",
    "red": "#e04b40ff",
    "white": "#ffffffff",
}

plt.rcParams.update(
    {
        "axes.spines.right": False,
        "axes.spines.top": False,
        "axes.prop_cycle": cycler(color=[colors["blue"], colors["red"]]),
    }
)

# %% [markdown]
# ### Plot training error
# We begin with two plots visualizing the training error of the network: the loss and the recall error, both
# plotted against the iterations.

# %%
fig, axs = plt.subplots(2, 1, sharex=True)

axs[0].plot(range(1, n_iter + 1), loss)
axs[0].set_ylabel(r"$E = -\sum_{t,k} \pi_k^{*,t} \log \pi_k^t$")

axs[1].plot(range(1, n_iter + 1), recall_errors)
axs[1].set_ylabel("recall errors")

axs[-1].set_xlabel("training iteration")
axs[-1].set_xlim(1, n_iter)
axs[-1].xaxis.get_major_locator().set_params(integer=True)

fig.tight_layout()

# %%
# calculate the loss with mean squared error
loss_mse = np.mean(np.sum((target_signal - readout_signal) ** 2, axis=0), axis=(1, 2))

# plot the loss with mean squared error
plt.figure()
plt.plot(range(1, n_iter + 1), loss_mse)
plt.xlabel("training iteration")
plt.ylabel("mean squared error")    
plt.show()

# %% [markdown]
# ### Plot spikes and dynamic variables
# This plotting routine shows how to plot all of the recorded dynamic variables and spikes across time. We take
# one snapshot in the first iteration and one snapshot at the end.

# %%
def plot_recordable(ax, events, recordable, ylabel, xlims):
    for sender in set(events["senders"]):
        idc_sender = events["senders"] == sender
        idc_times = (events["times"][idc_sender] > xlims[0]) & (events["times"][idc_sender] < xlims[1])
        ax.plot(events["times"][idc_sender][idc_times], events[recordable][idc_sender][idc_times], lw=0.5)
    ax.set_ylabel(ylabel)
    margin = np.abs(np.max(events[recordable]) - np.min(events[recordable])) * 0.1
    ax.set_ylim(np.min(events[recordable]) - margin, np.max(events[recordable]) + margin)


def plot_spikes(ax, events, nrns, ylabel, xlims):
    idc_times = (events["times"] > xlims[0]) & (events["times"] < xlims[1])
    idc_sender = np.isin(events["senders"][idc_times], nrns.tolist())
    senders_subset = events["senders"][idc_times][idc_sender]
    times_subset = events["times"][idc_times][idc_sender]

    ax.scatter(times_subset, senders_subset, s=0.1)
    ax.set_ylabel(ylabel)
    margin = np.abs(np.max(senders_subset) - np.min(senders_subset)) * 0.1
    ax.set_ylim(np.min(senders_subset) - margin, np.max(senders_subset) + margin)


for xlims in [(0, steps["sequence"]), (steps["task"] - steps["sequence"], steps["task"])]:
    fig, axs = plt.subplots(14, 1, sharex=True, figsize=(8, 14), gridspec_kw={"hspace": 0.4, "left": 0.2})

    plot_spikes(axs[0], events_sr, nrns_in, r"$z_i$" + "\n", xlims)
    plot_spikes(axs[1], events_sr, nrns_reg, r"$z_j$" + "\n", xlims)

    plot_recordable(axs[2], events_mm_reg, "V_m", r"$v_j$" + "\n(mV)", xlims)
    plot_recordable(axs[3], events_mm_reg, "surrogate_gradient", r"$\psi_j$" + "\n", xlims)
    plot_recordable(axs[4], events_mm_reg, "learning_signal", r"$L_j$" + "\n(pA)", xlims)

    plot_spikes(axs[5], events_sr, nrns_ad, r"$z_j$" + "\n", xlims)

    plot_recordable(axs[6], events_mm_ad, "V_m", r"$v_j$" + "\n(mV)", xlims)
    plot_recordable(axs[7], events_mm_ad, "surrogate_gradient", r"$\psi_j$" + "\n", xlims)
    plot_recordable(axs[8], events_mm_ad, "V_th_adapt", r"$A_j$" + "\n(mV)", xlims)
    plot_recordable(axs[9], events_mm_ad, "learning_signal", r"$L_j$" + "\n(pA)", xlims)

    plot_recordable(axs[10], events_mm_out, "V_m", r"$v_k$" + "\n(mV)", xlims)
    plot_recordable(axs[11], events_mm_out, "target_signal", r"$\pi^*_k$" + "\n", xlims)
    plot_recordable(axs[12], events_mm_out, "readout_signal", r"$\pi_k$" + "\n", xlims)
    plot_recordable(axs[13], events_mm_out, "error_signal", r"$\pi_k-\pi^*_k$" + "\n", xlims)

    axs[-1].set_xlabel(r"$t$ (ms)")
    axs[-1].set_xlim(*xlims)

    fig.align_ylabels()
# Out:
# /tmp/ipykernel_786807/313335882.py:8: UserWarning:Attempting to set identical low and high ylims makes transformation singular; automatically expanding.

# %% [markdown]
# ### Plot weight time courses
# Similarly, we can plot the weight histories. Note that the weight recorder, attached to the synapses, works
# differently than the other recorders. Since synapses only get activated when they transmit a spike, the weight
# recorder only records the weight in those moments. That is why the first weight registrations do not start in
# the first time step and we add the initial weights manually.

# %%
def plot_weight_time_course(ax, events, nrns_senders, nrns_targets, label, ylabel):
    for sender in nrns_senders.tolist():
        for target in nrns_targets.tolist():
            idc_syn = (events["senders"] == sender) & (events["targets"] == target)
            idc_syn_pre = (weights_pre_train[label]["source"] == sender) & (
                weights_pre_train[label]["target"] == target
            )

            times = [0.0] + events["times"][idc_syn].tolist()
            weights = [weights_pre_train[label]["weight"][idc_syn_pre]] + events["weights"][idc_syn].tolist()

            ax.step(times, weights, c=colors["blue"])
        ax.set_ylabel(ylabel)
        ax.set_ylim(-0.6, 0.6)


fig, axs = plt.subplots(3, 1, sharex=True, figsize=(3, 4))

plot_weight_time_course(axs[0], events_wr, nrns_in[:n_record_w], nrns_rec[:n_record_w], "in_rec", r"in (pA)")
plot_weight_time_course(
    axs[1], events_wr, nrns_rec[:n_record_w], nrns_rec[:n_record_w], "rec_rec", r"rec (pA)"
)
plot_weight_time_course(axs[2], events_wr, nrns_rec[:n_record_w], nrns_out, "rec_out", r"out (pA)")

axs[-1].set_xlabel(r"$t$ (ms)")
axs[-1].set_xlim(0, steps["task"])

fig.align_ylabels()
fig.tight_layout()

# %% [markdown]
# ### Plot weight matrices
# If one is not interested in the time course of the weights, it is possible to read out only the initial and
# final weights, which requires less computing time and memory than the weight recorder approach. Here, we plot
# the corresponding weight matrices before and after the optimization.

# %%
cmap = mpl.colors.LinearSegmentedColormap.from_list(
    "cmap", ((0.0, colors["blue"]), (0.5, colors["white"]), (1.0, colors["red"]))
)

fig, axs = plt.subplots(3, 2, sharex="col", sharey="row")

all_w_extrema = []

for k in weights_pre_train.keys():
    w_pre = weights_pre_train[k]["weight"]
    w_post = weights_post_train[k]["weight"]
    all_w_extrema.append([np.min(w_pre), np.max(w_pre), np.min(w_post), np.max(w_post)])

args = {"cmap": cmap, "vmin": np.min(all_w_extrema), "vmax": np.max(all_w_extrema)}

for i, weights in zip([0, 1], [weights_pre_train, weights_post_train]):
    axs[0, i].pcolormesh(weights["in_rec"]["weight_matrix"].T, **args)
    axs[1, i].pcolormesh(weights["rec_rec"]["weight_matrix"], **args)
    cmesh = axs[2, i].pcolormesh(weights["rec_out"]["weight_matrix"], **args)

    axs[2, i].set_xlabel("recurrent\nneurons")

axs[0, 0].set_ylabel("input\nneurons")
axs[1, 0].set_ylabel("recurrent\nneurons")
axs[2, 0].set_ylabel("readout\nneurons")
fig.align_ylabels(axs[:, 0])

axs[0, 0].text(0.5, 1.1, "pre-training", transform=axs[0, 0].transAxes, ha="center")
axs[0, 1].text(0.5, 1.1, "post-training", transform=axs[0, 1].transAxes, ha="center")

axs[2, 0].yaxis.get_major_locator().set_params(integer=True)

cbar = plt.colorbar(cmesh, cax=axs[1, 1].inset_axes([1.1, 0.2, 0.05, 0.8]), label="weight (pA)")

fig.tight_layout()

plt.show()
